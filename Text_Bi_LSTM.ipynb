# %%
'''
this is a Bi_Lstm model, which will be used for text classification
Teng Li
06,Dec,2021
'''
# Out:
# '\nthis is a Bi_Lstm model, which will be used for text classification\nTeng Li\n06,Dec,2021\n'

# %%
from config import DefaultConfig
import torch
import torch.nn as nn
import torch.nn.functional as f
import os
from utils import load_flattened_documents, load_datasets
from datasets_preprocessing import clean_datasets, Movie_Classif_Dataset
from torch.utils.data import DataLoader
from Bi_LSTM import Text_Bi_LSTM, lstm_padding
import wandb

# %%
# first of all get config
Conf = DefaultConfig()

DEVICE = Conf.device
LR = Conf.lr
BATCH_SIZE = 3 # get from Conf.lstm_batch_size
PRINT_FREQ = 30
#INPUT_SIZE = 300 # get from Conf.input_size
#HIDDEN_SIZE = 50 # get from Conf.hidden_size
#NUM_LAYERS = 2   # get from Conf.num_layers
#BIDIRECTIONAL = 2   #get from Conf.bidirectional
#NUM_CLASS = 2    # get from Conf.num_class

# %%
#load raw datasets
data_root = os.path.join('Data', 'movies')
documents = load_flattened_documents(data_root,None)
documents = clean_datasets(documents)
train, val, test = load_datasets(data_root)
#load Train_Dataset
Train_Dataset = Movie_Classif_Dataset(documents,train)
#load into DataLoader
Loader = DataLoader(dataset = Train_Dataset,
                    batch_size = BATCH_SIZE,
                    shuffle=True,
                    collate_fn=lstm_padding,
                    drop_last=True)

# %%
if os.path.exists('Text_lstm_1.pth'):
    if torch.cuda.is_available():
        Text_lstm = torch.load('Text_lstm_1.pth').cuda()
    else:
        Text_lstm = torch.load('Text_lstm_1.pth')
    print('load from Text_lstm_1.pth')
# Out:
# load from Text_lstm_1.pth

# %%
Text_lstm = Text_Bi_LSTM()

# %%
def lstm_train(epochs,model,dataloader,device,Lr):
    model.train()
    loss_func = nn.NLLLoss()
    optimizer = torch.optim.Adam(model.parameters(),lr=Lr)
    model.to(device)
    for e in range(epochs):
        loss_sum = 0
        acc = 0
        for i,(x,y) in enumerate(dataloader):
            # load x,y
            x = x.to(device)
            y = y.to(device)
            # predict
            y_hat = model(x)
            # comput loss and acc
            loss = loss_func(y_hat,y)
            label_hat = torch.argmax(y_hat,dim=1)
            acc += torch.sum(label_hat == y).item()
            loss_sum += loss
            # backward propagation
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            # print info
            if (i+1)%PRINT_FREQ == 0:
                acc = acc/(BATCH_SIZE*PRINT_FREQ)
                loss_average = loss_sum/PRINT_FREQ
                wandb.log({"loss": loss_average.data,"acc":acc})
                wandb.watch(model)
                print('epoch:{}, batch:{}, loss:{}, acc:{}'.format(e,i+1,loss_average.data,acc))
                loss_sum = 0
                acc = 0


wandb.init(project='Lstm',entity='teng_li')
lstm_train(10,Text_lstm,Loader,DEVICE,0.001)
# Out:
# wandb: Currently logged in as: teng_li (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.10 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/teng_li/Lstm/runs/nry2lgxw" target="_blank">different-rain-6</a></strong> to <a href="https://wandb.ai/teng_li/Lstm" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# epoch:0, batch:30, loss:0.7034931182861328, acc:0.5111111111111111
# epoch:0, batch:60, loss:0.6952469944953918, acc:0.4777777777777778
# epoch:0, batch:90, loss:0.6964959502220154, acc:0.4444444444444444
# epoch:0, batch:120, loss:0.6975261569023132, acc:0.4444444444444444
# epoch:0, batch:150, loss:0.6871842741966248, acc:0.6
# epoch:0, batch:180, loss:0.6942881345748901, acc:0.5444444444444444
# epoch:0, batch:210, loss:0.6934261918067932, acc:0.4888888888888889
# epoch:0, batch:240, loss:0.6979597806930542, acc:0.5222222222222223
# epoch:0, batch:270, loss:0.7000595331192017, acc:0.43333333333333335
# epoch:0, batch:300, loss:0.6940596103668213, acc:0.4666666666666667
# epoch:0, batch:330, loss:0.6889504790306091, acc:0.5555555555555556
# epoch:0, batch:360, loss:0.6865410208702087, acc:0.5666666666666667
# epoch:0, batch:390, loss:0.7021137475967407, acc:0.4777777777777778
# epoch:0, batch:420, loss:0.6945987343788147, acc:0.5666666666666667
# epoch:0, batch:450, loss:0.6941998600959778, acc:0.5111111111111111
# epoch:0, batch:480, loss:0.6905242800712585, acc:0.5222222222222223
# epoch:0, batch:510, loss:0.6885154247283936, acc:0.5777777777777777
# epoch:1, batch:30, loss:0.6639307737350464, acc:0.5777777777777777
# epoch:1, batch:60, loss:0.6123753190040588, acc:0.7777777777777778
# epoch:1, batch:90, loss:0.6431019902229309, acc:0.7111111111111111
# epoch:1, batch:120, loss:0.5746191740036011, acc:0.7111111111111111
# epoch:1, batch:150, loss:0.5909039378166199, acc:0.6777777777777778
# epoch:1, batch:180, loss:0.5049196481704712, acc:0.8111111111111111
# epoch:1, batch:210, loss:0.5457741022109985, acc:0.7666666666666667
# epoch:1, batch:240, loss:0.4800192713737488, acc:0.7444444444444445
# epoch:1, batch:270, loss:0.5616433620452881, acc:0.7222222222222222
# epoch:1, batch:300, loss:0.573662519454956, acc:0.6777777777777778
# epoch:1, batch:330, loss:0.5331534743309021, acc:0.7444444444444445
# epoch:1, batch:360, loss:0.551005482673645, acc:0.7777777777777778
# epoch:1, batch:390, loss:0.48131588101387024, acc:0.7444444444444445
# epoch:1, batch:420, loss:0.5057176947593689, acc:0.7666666666666667
# epoch:1, batch:450, loss:0.622212827205658, acc:0.6555555555555556
# epoch:1, batch:480, loss:0.4622306525707245, acc:0.8111111111111111
# epoch:1, batch:510, loss:0.6185434460639954, acc:0.6555555555555556
# epoch:2, batch:30, loss:0.25374874472618103, acc:0.9222222222222223
# epoch:2, batch:60, loss:0.10991405695676804, acc:0.9666666666666667
# epoch:2, batch:90, loss:0.10811637341976166, acc:0.9777777777777777
# epoch:2, batch:120, loss:0.293094664812088, acc:0.9222222222222223
# epoch:2, batch:150, loss:0.11731914430856705, acc:0.9555555555555556
# epoch:2, batch:180, loss:0.1303998827934265, acc:0.9555555555555556
# epoch:2, batch:210, loss:0.17620451748371124, acc:0.9333333333333333
# epoch:2, batch:240, loss:0.26192930340766907, acc:0.8888888888888888
# epoch:2, batch:270, loss:0.17088504135608673, acc:0.9333333333333333
# epoch:2, batch:300, loss:0.23039010167121887, acc:0.9
# epoch:2, batch:330, loss:0.15937386453151703, acc:0.9222222222222223
# epoch:2, batch:360, loss:0.16222549974918365, acc:0.9333333333333333
# epoch:2, batch:390, loss:0.08693284541368484, acc:0.9666666666666667
# epoch:2, batch:420, loss:0.20605094730854034, acc:0.9333333333333333
# epoch:2, batch:450, loss:0.3548852801322937, acc:0.8777777777777778
# epoch:2, batch:480, loss:0.25779974460601807, acc:0.9
# epoch:2, batch:510, loss:0.17403702437877655, acc:0.9555555555555556
# epoch:3, batch:30, loss:0.04772906005382538, acc:0.9888888888888889
# epoch:3, batch:60, loss:0.06366521865129471, acc:0.9555555555555556
# epoch:3, batch:90, loss:0.0363490954041481, acc:0.9888888888888889
# epoch:3, batch:120, loss:0.028079014271497726, acc:0.9888888888888889
# epoch:3, batch:150, loss:0.024951310828328133, acc:0.9777777777777777
# epoch:3, batch:180, loss:0.06091231480240822, acc:0.9777777777777777
# epoch:3, batch:210, loss:0.010571332648396492, acc:1.0
# epoch:3, batch:240, loss:0.0656840056180954, acc:0.9777777777777777
# epoch:3, batch:270, loss:0.030785636976361275, acc:0.9777777777777777
# epoch:3, batch:300, loss:0.016203615814447403, acc:1.0
# epoch:3, batch:330, loss:0.01748269610106945, acc:0.9888888888888889
# epoch:3, batch:360, loss:0.04713248461484909, acc:0.9888888888888889
# epoch:3, batch:390, loss:0.11009477823972702, acc:0.9555555555555556
# epoch:3, batch:420, loss:0.08805473893880844, acc:0.9666666666666667
# epoch:3, batch:450, loss:0.07870392501354218, acc:0.9666666666666667
# epoch:3, batch:480, loss:0.013756023719906807, acc:1.0
# epoch:3, batch:510, loss:0.02558811753988266, acc:0.9777777777777777
# epoch:4, batch:30, loss:0.007434696424752474, acc:1.0
# epoch:4, batch:60, loss:0.004507445264607668, acc:1.0
# epoch:4, batch:90, loss:0.005228343885391951, acc:1.0
# epoch:4, batch:120, loss:0.008401365950703621, acc:1.0
# epoch:4, batch:150, loss:0.008697458542883396, acc:1.0
# epoch:4, batch:180, loss:0.002504737814888358, acc:1.0
# epoch:4, batch:210, loss:0.012370271608233452, acc:0.9888888888888889
# epoch:4, batch:240, loss:0.00997879821807146, acc:1.0
# epoch:4, batch:270, loss:0.0029573324136435986, acc:1.0
# epoch:4, batch:300, loss:0.07659051567316055, acc:0.9888888888888889
# epoch:4, batch:330, loss:0.0029123197309672832, acc:1.0
# epoch:4, batch:360, loss:0.0012173426803201437, acc:1.0
# epoch:4, batch:390, loss:0.003689804347231984, acc:1.0
# epoch:4, batch:420, loss:0.010378477163612843, acc:1.0
# epoch:4, batch:450, loss:0.005922545213252306, acc:1.0
# epoch:4, batch:480, loss:0.0005687922821380198, acc:1.0
# epoch:4, batch:510, loss:0.0013091156724840403, acc:1.0
# epoch:5, batch:30, loss:0.0001586741564096883, acc:1.0
# epoch:5, batch:60, loss:0.0003685185802169144, acc:1.0
# epoch:5, batch:90, loss:0.0011738404864445329, acc:1.0
# epoch:5, batch:120, loss:0.001426182920113206, acc:1.0
# epoch:5, batch:150, loss:0.00012981760664843023, acc:1.0
# epoch:5, batch:180, loss:0.0004436528543010354, acc:1.0
# epoch:5, batch:210, loss:0.0009724575793370605, acc:1.0
# epoch:5, batch:240, loss:7.276589894900098e-05, acc:1.0
# epoch:5, batch:270, loss:0.001070002093911171, acc:1.0
# epoch:5, batch:300, loss:0.001261353027075529, acc:1.0
# epoch:5, batch:330, loss:0.00016642244008835405, acc:1.0
# epoch:5, batch:360, loss:0.0003963154158554971, acc:1.0
# epoch:5, batch:390, loss:0.00015546948998235166, acc:1.0
# epoch:5, batch:420, loss:0.008029199205338955, acc:1.0
# epoch:5, batch:450, loss:0.001367187243886292, acc:1.0
# epoch:5, batch:480, loss:0.00039937678957358, acc:1.0
# epoch:5, batch:510, loss:0.0006264368421398103, acc:1.0
# epoch:6, batch:30, loss:5.851847163285129e-05, acc:1.0
# epoch:6, batch:60, loss:0.0004174703499302268, acc:1.0
# epoch:6, batch:90, loss:0.00020855854381807148, acc:1.0
# epoch:6, batch:120, loss:9.581191261531785e-05, acc:1.0
# epoch:6, batch:150, loss:0.0001894965098472312, acc:1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-a5ca6a7d9a5f> in <module>
#      34
#      35 wandb.init(project='Lstm',entity='teng_li')
# ---> 36 lstm_train(10,Text_lstm,Loader,DEVICE,0.001)
#
# <ipython-input-6-a5ca6a7d9a5f> in lstm_train(epochs, model, dataloader, device, Lr)
#      21             optimizer.zero_grad()
#      22             loss.backward()
# ---> 23             optimizer.step()
#      24             # print info
#      25             if (i+1)%PRINT_FREQ == 0:
#
# ~/anaconda3/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      13         def decorate_context(*args, **kwargs):
#      14             with self:
# ---> 15                 return func(*args, **kwargs)
#      16         return decorate_context
#      17
#
# ~/anaconda3/lib/python3.7/site-packages/torch/optim/adam.py in step(self, closure)
#     105                     denom = (max_exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(group['eps'])
#     106                 else:
# --> 107                     denom = (exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(group['eps'])
#     108
#     109                 step_size = group['lr'] / bias_correction1
#
# KeyboardInterrupt:

# %%
# save the model
torch.save(Text_lstm,'Text_lstm_1.pth')
# Out:
# /home/teng/anaconda3/lib/python3.7/site-packages/torch/serialization.py:402: UserWarning: Couldn't retrieve source code for container of type Text_Bi_LSTM. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
acc = 0
for i,(x,y) in enumerate(Loader):
    Text_lstm.eval()
    x = x.to(DEVICE)
    y = y.to(DEVICE)
    y_hat = Text_lstm(x)
    label_hat = torch.argmax(y_hat,dim=1)
    acc += torch.sum(label_hat == y).item()
    if i == 39:
        break
print(acc/120)
# Out:
# 0.5583333333333333

# %%
#load raw datasets
data_root = os.path.join('Data', 'movies')
documents = load_flattened_documents(data_root,None)
documents = clean_datasets(documents)
train, val, test = load_datasets(data_root)
#load Train_Dataset
Val_Dataset = Movie_Classif_Dataset(documents,val)
#load into DataLoader
Loader = DataLoader(dataset = Val_Dataset,
                    batch_size = BATCH_SIZE,
                    shuffle=False,
                    collate_fn=lstm_padding,
                    drop_last=True)

# %%
from utils import load_documents
from Text_Cnn import get_vocab_list
from datasets_preprocessing import get_word_tag_dict
'''
step 6.0:get word_level documents and sentence_level documents, the tag_dict, and some config
'''
data_root = os.path.join('Data', 'movies')
word_level_docs = clean_datasets(load_flattened_documents(data_root,None))
sent_level_docs = load_documents(data_root)

# loss function
loss_func = nn.NLLLoss()
# first of all we need to load Vocab
Vocab_list = get_vocab_list()

#some conf of hotflip
vocab_size = Conf.search_size    # get from Conf.search_size
beam_size = Conf.beam_search_size # get from Conf.beam_search_size
change_word_num = Conf.change_word_num # get from Conf.change_word_num

# get word tag dict from given sent_level_documents
word_tag_dict = get_word_tag_dict(sent_level_docs)

# %%
# hotflip with constrain

import heapq
from Text_Cnn import class_to_tensor
from datasets_preprocessing import doc_to_tag, get_part_of_speech, get_wi_tag

loss_incre_sum = 0
for i,(x,y) in enumerate(Loader):
    #print(x[0].shape)
    # compute y_hat
    y_hat = Text_lstm(x)
    # record the loss before hotflip
    loss_before = loss_func(y_hat[:1],y[:1]).item()
    print('loss before hotflip:', loss_before)
    #get docid
    #docids = [train[i*3+1].annotation_id,train[i*3+2].annotation_id,train[i*3+3].annotation_id]
    docid = val[i*3+1].annotation_id
    print(docid)
    # get word_level and sent_level doc
    #word_docs = [word_level_docs[docids[0]],word_level_docs[docids[1]],word_level_docs[docids[2]]]
    word_doc = word_level_docs[docid]
    #sent_docs = [sent_level_docs[docids[0]],sent_level_docs[docids[1]],sent_level_docs[docids[2]]]
    sent_doc = sent_level_docs[docid]
    # get word_tag
    #words_tag = [doc_to_tag(sent_docs[0]),doc_to_tag(sent_docs[1]),doc_to_tag(sent_docs[2])]
    words_tag = doc_to_tag(sent_doc)
    for n in range(change_word_num):
        print('flip time:',n+1)
        # step 6.1: get gradient
        gradient = Text_lstm.get_gradient(x,y)
        #print(gradient[0].shape)
        # step 6.2: get best w0
        w0_list = []# a set to record mean loss of each w0
        for w0_place,w0 in enumerate(word_doc):
            w0_id =x[0][w0_place]
            w0_embed = Text_lstm.get_word_embedding(w0_id)
            #print(w0_embed.shape)
            w0_gradient = gradient[0][0][w0_place]
            #print(w0_gradient.shape)
            if w0_gradient.sum() != 0:
                w0_loss_estimate = torch.dot(w0_gradient,w0_embed).item()
                w0_list.append({'w0':w0,'w0_place':w0_place,'w0_gradient':w0_gradient,
                                'w0_embed':w0_embed,'w0_loss_estimate':w0_loss_estimate})
        # now let's get best w0 list
        best_w0 = heapq.nsmallest(beam_size,w0_list,key=lambda s: s['w0_loss_estimate'])
        #print(best_w0)
        
        #step 6.3: the best word(wi) for each filped word (max (w0_gradient * wi_embed))
        final_list = []
        for w0_info in best_w0:
            w0 = w0_info['w0']
            #print('w0',w0)
            w0_place = w0_info['w0_place']
            #print('w0_palce',w0_place)
            w0_tag = words_tag[w0_place]        
            best_wi = {'wi_id':None,'wi_embed':None,'wi_loss_estimate':0}
            #print('best wi refresh')
            w0_gradient = w0_info['w0_gradient']
            for wi_id in range(vocab_size):
                # get word wi
                wi_index = torch.tensor(wi_id)
                wi = Vocab_list[wi_id]
                # get the tag of wi
                if wi in word_tag_dict:
                    wi_tag = word_tag_dict[wi]
                else:
                    wi_tag = set()
                    wi_tag.add(get_part_of_speech(wi))
                #check w0_tag and wi_tag, if not same, skip to next word
                if w0_tag not in wi_tag:
                    continue
                # check if the tag changed after flip. if changed, skip
                tag = get_wi_tag(sent_doc,w0_place,wi)
                if tag != w0_tag:
                    continue
                # up to now the wi is qualified, then we can record the best wi
                wi_embed = Text_lstm.get_word_embedding(wi_index)
                wi_loss_estimate = torch.dot(w0_gradient,wi_embed).item()
                if wi_loss_estimate > best_wi['wi_loss_estimate']:
                    #print(wi)
                    best_wi['wi_id'] = wi_id
                    best_wi['wi_embed'] = wi_embed
                    best_wi['wi_loss_estimate'] = wi_loss_estimate
            #now we get best wi for w0
            if best_wi['wi_loss_estimate'] == 0:
                #print('no wi')
                continue
            w0_embed = w0_info['w0_embed']
            #print(w0_embed.shape)
            wi_embed = best_wi['wi_embed']
            #print(wi_embed.shape)
            embed_diff = wi_embed - w0_embed
            loss_estimate = torch.dot(w0_gradient,embed_diff).item()
            final_list.append({'w0':w0_info['w0'],'w0_place':w0_info['w0_place'],'wi_id':best_wi['wi_id'],
                               'wi':Vocab_list[best_wi['wi_id']],'loss_estimate':loss_estimate})
            
        # then step 6.4: get best w0 and wi
        final_filp = heapq.nlargest(1,final_list,key=lambda s:s['loss_estimate'])[0]
        print(final_filp)
        w0_place = final_filp['w0_place']
        wi_id = final_filp['wi_id']
        wi = final_filp['wi']
        
        # step 6.5: replace w0 with wi
        x[0][w0_place] = wi_id
        word_doc[w0_place] = wi
        # comput loss after this flip
        y_hat = Text_lstm(x)
        loss = loss_func(y_hat,y).item()
        
        
    # record loss increased 
    print('mean loss increased record:',(loss-loss_before)/change_word_num)
    loss_incre_sum += (loss-loss_before)/change_word_num
    print('doc_num:',i+1)
    print('average up to now:',loss_incre_sum/(i+1))
# Out:
# loss before hotflip: 0.1413482129573822
# negR_801.txt
# flip time: 1
# {'w0': 'hitchcock', 'w0_place': 1, 'wi_id': 1158, 'wi': 'contact', 'loss_estimate': 0.1594056934118271}
# flip time: 2
# {'w0': 'according', 'w0_place': 0, 'wi_id': 1429, 'wi': 'losing', 'loss_estimate': 1.2970805168151855}
# flip time: 3
# {'w0': 'gas', 'w0_place': 8, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.8442410230636597}
# flip time: 4
# {'w0': 'diners', 'w0_place': 7, 'wi_id': 488, 'wi': 'others', 'loss_estimate': 0.4847698211669922}
# flip time: 5
# {'w0': 'other', 'w0_place': 3, 'wi_id': 678, 'wi': 'annual', 'loss_estimate': 0.2064584344625473}
# mean loss increased record: 0.7453179657459259
# doc_num: 1
# average up to now: 0.7453179657459259
# loss before hotflip: 5.255608558654785
# negR_804.txt
# flip time: 1
# {'w0': 'for', 'w0_place': 0, 'wi_id': 420, 'wi': 'near', 'loss_estimate': 0.5915592312812805}
# flip time: 2
# {'w0': 'oldman', 'w0_place': 5, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.38450807332992554}
# flip time: 3
# {'w0': 'his', 'w0_place': 1, 'wi_id': 30, 'wi': 'their', 'loss_estimate': 0.18526975810527802}
# flip time: 4
# {'w0': 'personal', 'w0_place': 8, 'wi_id': 678, 'wi': 'annual', 'loss_estimate': 0.0863889828324318}
# flip time: 5
# {'w0': 'chose', 'w0_place': 6, 'wi_id': 548, 'wi': 'began', 'loss_estimate': 0.03986857831478119}
# mean loss increased record: -0.1799072265625
# doc_num: 2
# average up to now: 0.28270536959171294
# loss before hotflip: 0.05398141220211983
# negR_807.txt
# flip time: 1
# {'w0': 'thought', 'w0_place': 1, 'wi_id': 745, 'wi': 'straight', 'loss_estimate': 0.04309188574552536}
# flip time: 2
# {'w0': 'stigmata', 'w0_place': 3, 'wi_id': 992, 'wi': 'questions', 'loss_estimate': 0.34612515568733215}
# flip time: 3
# {'w0': '"', 'w0_place': 2, 'wi_id': 1821, 'wi': 'Act', 'loss_estimate': 0.5883876085281372}
# flip time: 4
# {'w0': 'thriller', 'w0_place': 11, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.26117825508117676}
# flip time: 5
# {'w0': 'oriented', 'w0_place': 10, 'wi_id': 211, 'wi': 'set', 'loss_estimate': 0.5386425256729126}
# mean loss increased record: 0.5475240968167782
# doc_num: 3
# average up to now: 0.37097827866673466
# loss before hotflip: 1.892557144165039
# negR_810.txt
# flip time: 1
# {'w0': 'comedy', 'w0_place': 10, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 1.4095933437347412}
# flip time: 2
# {'w0': 'i', 'w0_place': 0, 'wi_id': 1796, 'wi': 'natural', 'loss_estimate': 0.8279886245727539}
# flip time: 3
# {'w0': 'it', 'w0_place': 2, 'wi_id': 22, 'wi': 'he', 'loss_estimate': 0.28477591276168823}
# flip time: 4
# {'w0': 'had', 'w0_place': 7, 'wi_id': 548, 'wi': 'began', 'loss_estimate': 0.11905670166015625}
# flip time: 5
# {'w0': 'for', 'w0_place': 9, 'wi_id': 1124, 'wi': 'toward', 'loss_estimate': 0.031310927122831345}
# mean loss increased record: 0.6187279701232911
# doc_num: 4
# average up to now: 0.4329157015308738
# loss before hotflip: 0.3776341676712036
# negR_813.txt
# flip time: 1
# {'w0': 'fan', 'w0_place': 4, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.23534861207008362}
# flip time: 2
# {'w0': 'i', 'w0_place': 0, 'wi_id': 1158, 'wi': 'contact', 'loss_estimate': 1.0427913665771484}
# flip time: 3
# {'w0': 'seagal', 'w0_place': 3, 'wi_id': 678, 'wi': 'annual', 'loss_estimate': 0.6046417951583862}
# flip time: 4
# {'w0': 'awhile', 'w0_place': 788, 'wi_id': 1260, 'wi': 'fun', 'loss_estimate': 0.47839006781578064}
# flip time: 5
# {'w0': 'in', 'w0_place': 787, 'wi_id': 1634, 'wi': 'via', 'loss_estimate': 0.2762587070465088}
# mean loss increased record: 0.7024921178817749
# doc_num: 5
# average up to now: 0.486830984801054
# loss before hotflip: 0.05598564073443413
# negR_816.txt
# flip time: 1
# {'w0': "'m", 'w0_place': 4, 'wi_id': 811, 'wi': 'create', 'loss_estimate': 0.08031969517469406}
# flip time: 2
# {'w0': 'seems', 'w0_place': 1, 'wi_id': 986, 'wi': 'remains', 'loss_estimate': 0.5389077663421631}
# flip time: 3
# {'w0': 'i', 'w0_place': 3, 'wi_id': 608, 'wi': 'chance', 'loss_estimate': 0.43943220376968384}
# flip time: 4
# {'w0': 'basis', 'w0_place': 11, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.3881145119667053}
# flip time: 5
# {'w0': 'horror', 'w0_place': 7, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.08393186330795288}
# mean loss increased record: 0.4690347291529179
# doc_num: 6
# average up to now: 0.4838649421930313
# loss before hotflip: 1.225893497467041
# negR_819.txt
# flip time: 1
# {'w0': 'stallone', 'w0_place': 1, 'wi_id': 1158, 'wi': 'contact', 'loss_estimate': 0.5423332452774048}
# flip time: 2
# {'w0': 'films', 'w0_place': 6, 'wi_id': 1636, 'wi': 'boys', 'loss_estimate': 0.6117488145828247}
# flip time: 3
# {'w0': 'crap', 'w0_place': 5, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.3554650545120239}
# flip time: 4
# {'w0': 'this', 'w0_place': 11, 'wi_id': 223, 'wi': 'each', 'loss_estimate': 0.1418374925851822}
# flip time: 5
# {'w0': 'lifetime', 'w0_place': 9, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.0657668262720108}
# mean loss increased record: 0.2678385734558105
# doc_num: 7
# average up to now: 0.45300403237342834
# loss before hotflip: 4.131824970245361
# negR_822.txt
# flip time: 1
# {'w0': 'camp', 'w0_place': 5, 'wi_id': 678, 'wi': 'annual', 'loss_estimate': 1.410143256187439}
# flip time: 2
# {'w0': 'year', 'w0_place': 3, 'wi_id': 1158, 'wi': 'contact', 'loss_estimate': 0.3570464253425598}
# flip time: 3
# {'w0': 'power', 'w0_place': 531, 'wi_id': 636, 'wi': 'music', 'loss_estimate': 0.2826709747314453}
# flip time: 4
# {'w0': 'them', 'w0_place': 532, 'wi_id': 909, 'wi': 'themselves', 'loss_estimate': 0.27042049169540405}
# flip time: 5
# {'w0': 'is', 'w0_place': 4, 'wi_id': 986, 'wi': 'remains', 'loss_estimate': 0.10704591870307922}
# mean loss increased record: -0.17800726890563964
# doc_num: 8
# average up to now: 0.37412761971354486
# loss before hotflip: 0.41001805663108826
# negR_825.txt
# flip time: 1
# {'w0': 'able', 'w0_place': 4, 'wi_id': 764, 'wi': 'personal', 'loss_estimate': 0.5398772954940796}
# flip time: 2
# {'w0': 'anyone', 'w0_place': 1, 'wi_id': 1158, 'wi': 'contact', 'loss_estimate': 0.9604977965354919}
# flip time: 3
# {'w0': 'in', 'w0_place': 5, 'wi_id': 1124, 'wi': 'toward', 'loss_estimate': 0.23253807425498962}
# flip time: 4
# {'w0': 'forsee', 'w0_place': 7, 'wi_id': 811, 'wi': 'create', 'loss_estimate': 0.06343035399913788}
# flip time: 5
# {'w0': '1983', 'w0_place': 6, 'wi_id': 81, 'wi': 'million', 'loss_estimate': 0.06307107210159302}
# mean loss increased record: 0.5103196442127228
# doc_num: 9
# average up to now: 0.38926006688012016
# loss before hotflip: 3.417342185974121
# negR_828.txt
# flip time: 1
# {'w0': 'are', 'w0_place': 4, 'wi_id': 811, 'wi': 'create', 'loss_estimate': 1.0115201473236084}
# flip time: 2
# {'w0': 'people', 'w0_place': 7, 'wi_id': 992, 'wi': 'questions', 'loss_estimate': 0.2920927107334137}
# flip time: 3
# {'w0': 'you', 'w0_place': 3, 'wi_id': 22, 'wi': 'he', 'loss_estimate': 0.08089665323495865}
# flip time: 4
# {'w0': 'preview', 'w0_place': 12, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.057913124561309814}
# flip time: 5
# {'w0': 'have', 'w0_place': 9, 'wi_id': 811, 'wi': 'create', 'loss_estimate': 0.03819497674703598}
# mean loss increased record: 0.1252039909362793
# doc_num: 10
# average up to now: 0.36285445928573606
# loss before hotflip: 4.111319065093994
# negR_831.txt
# flip time: 1
# {'w0': 'lumet', 'w0_place': 11, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.5127111077308655}
# flip time: 2
# {'w0': 'often', 'w0_place': 7, 'wi_id': 406, 'wi': 'along', 'loss_estimate': 0.15540888905525208}
# flip time: 3
# {'w0': 'director', 'w0_place': 9, 'wi_id': 571, 'wi': 'person', 'loss_estimate': 0.0569460391998291}
# flip time: 4
# {'w0': 'film', 'w0_place': 21, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.024530326947569847}
# flip time: 5
# {'w0': 'sidney', 'w0_place': 10, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.030645236372947693}
# mean loss increased record: -0.11838731765747071
# doc_num: 11
# average up to now: 0.3191052068363536
# loss before hotflip: 0.008273967541754246
# negR_834.txt
# flip time: 1
# {'w0': 'meg', 'w0_place': 1, 'wi_id': 1973, 'wi': 'screen', 'loss_estimate': 0.005521601065993309}
# flip time: 2
# {'w0': 'ryan', 'w0_place': 2, 'wi_id': 798, 'wi': 'opening', 'loss_estimate': 0.08614759147167206}
# flip time: 3
# {'w0': '"', 'w0_place': 0, 'wi_id': 678, 'wi': 'annual', 'loss_estimate': 0.5028536915779114}
# flip time: 4
# {'w0': 'comedy', 'w0_place': 7, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.5841948390007019}
# flip time: 5
# {'w0': 'irresistible', 'w0_place': 4, 'wi_id': 678, 'wi': 'annual', 'loss_estimate': 0.6671624779701233}
# mean loss increased record: 0.4963750584051013
# doc_num: 12
# average up to now: 0.33387769446708265
# loss before hotflip: 1.2611513137817383
# negR_837.txt
# flip time: 1
# {'w0': 'homosexual', 'w0_place': 4, 'wi_id': 678, 'wi': 'annual', 'loss_estimate': 1.5071110725402832}
# flip time: 2
# {'w0': 'disappointing', 'w0_place': 0, 'wi_id': 678, 'wi': 'annual', 'loss_estimate': 1.055666446685791}
# flip time: 3
# {'w0': 'about', 'w0_place': 2, 'wi_id': 1124, 'wi': 'toward', 'loss_estimate': 0.3970580995082855}
# flip time: 4
# {'w0': 'relationship', 'w0_place': 5, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.10631173849105835}
# flip time: 5
# {'w0': 'film', 'w0_place': 13, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.04954727366566658}
# mean loss increased record: 0.4344194412231445
# doc_num: 13
# average up to now: 0.3416116749867797
# loss before hotflip: 2.0872254371643066
# negR_840.txt
# flip time: 1
# {'w0': '"', 'w0_place': 3, 'wi_id': 811, 'wi': 'create', 'loss_estimate': 0.9852370023727417}
# flip time: 2
# {'w0': 'idle', 'w0_place': 1, 'wi_id': 678, 'wi': 'annual', 'loss_estimate': 0.7901126146316528}
# flip time: 3
# {'w0': 'distasteful', 'w0_place': 5, 'wi_id': 1865, 'wi': 'suspect', 'loss_estimate': 0.15758612751960754}
# flip time: 4
# {'w0': 'thought', 'w0_place': 11, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.04155943915247917}
# flip time: 5
# {'w0': 'crass', 'w0_place': 6, 'wi_id': 608, 'wi': 'chance', 'loss_estimate': 0.03216448426246643}
# mean loss increased record: 0.06899089813232422
# doc_num: 14
# average up to now: 0.3221387623543186
# loss before hotflip: 1.8634734153747559
# negR_843.txt
# flip time: 1
# {'w0': 'sutherland', 'w0_place': 2, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 2.0684220790863037}
# flip time: 2
# {'w0': 'kiefer', 'w0_place': 1, 'wi_id': 1158, 'wi': 'contact', 'loss_estimate': 0.7069324254989624}
# flip time: 3
# {'w0': 'reese', 'w0_place': 4, 'wi_id': 403, 'wi': 'current', 'loss_estimate': 0.2180977165699005}
# flip time: 4
# {'w0': 'history', 'w0_place': 2, 'wi_id': 1429, 'wi': 'losing', 'loss_estimate': 0.11013850569725037}
# flip time: 5
# {'w0': 'witherspoon', 'w0_place': 5, 'wi_id': 1158, 'wi': 'contact', 'loss_estimate': 0.0853424221277237}
# mean loss increased record: 0.151359224319458
# doc_num: 15
# average up to now: 0.31075345981866126
# loss before hotflip: 0.007733050733804703
# negR_846.txt
# flip time: 1
# {'w0': 'pair', 'w0_place': 4, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.011273812502622604}
# flip time: 2
# {'w0': 'gag', 'w0_place': 3, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.823079526424408}
# flip time: 3
# {'w0': 'kevin', 'w0_place': 8, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.5499627590179443}
# flip time: 4
# {'w0': 'from', 'w0_place': 6, 'wi_id': 1124, 'wi': 'toward', 'loss_estimate': 0.49003320932388306}
# flip time: 5
# {'w0': 'characters', 'w0_place': 5, 'wi_id': 451, 'wi': 'minutes', 'loss_estimate': 0.19989091157913208}
# mean loss increased record: 0.44757748767733574
# doc_num: 16
# average up to now: 0.3193049615598284
# loss before hotflip: 0.011856560595333576
# negR_849.txt
# flip time: 1
# {'w0': 'one', 'w0_place': 1, 'wi_id': 81, 'wi': 'million', 'loss_estimate': 0.012126240879297256}
# flip time: 2
# {'w0': 'themes', 'w0_place': 3, 'wi_id': 1668, 'wi': 'books', 'loss_estimate': 0.11899583041667938}
# flip time: 3
# {'w0': 'make', 'w0_place': 11, 'wi_id': 811, 'wi': 'create', 'loss_estimate': 0.439202219247818}
# flip time: 4
# {'w0': 'try', 'w0_place': 10, 'wi_id': 811, 'wi': 'create', 'loss_estimate': 0.8138155937194824}
# flip time: 5
# {'w0': 'midnight', 'w0_place': 846, 'wi_id': 1260, 'wi': 'fun', 'loss_estimate': 0.4759359061717987}
# mean loss increased record: 0.5452435484156013
# doc_num: 17
# average up to now: 0.3325954666689915
# loss before hotflip: 0.12976519763469696
# negR_852.txt
# flip time: 1
# {'w0': '/', 'w0_place': 4, 'wi_id': 764, 'wi': 'personal', 'loss_estimate': 0.1779804229736328}
# flip time: 2
# {'w0': 'marc', 'w0_place': 2, 'wi_id': 811, 'wi': 'create', 'loss_estimate': 1.2748956680297852}
# flip time: 3
# {'w0': 'spirit', 'w0_place': 641, 'wi_id': 1260, 'wi': 'fun', 'loss_estimate': 0.47765350341796875}
# flip time: 4
# {'w0': 'marc', 'w0_place': 13, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.373075395822525}
# flip time: 5
# {'w0': 'in', 'w0_place': 640, 'wi_id': 406, 'wi': 'along', 'loss_estimate': 0.30689114332199097}
# mean loss increased record: 1.0647711426019668
# doc_num: 18
# average up to now: 0.37327189310971237
# loss before hotflip: 4.721525192260742
# negR_855.txt
# flip time: 1
# {'w0': 'fourth', 'w0_place': 4, 'wi_id': 678, 'wi': 'annual', 'loss_estimate': 0.993593692779541}
# flip time: 2
# {'w0': 'bad', 'w0_place': 351, 'wi_id': 147, 'wi': 'next', 'loss_estimate': 0.5274999141693115}
# flip time: 3
# {'w0': 'too', 'w0_place': 350, 'wi_id': 1260, 'wi': 'fun', 'loss_estimate': 0.5086932182312012}
# flip time: 4
# {'w0': 'fallen', 'w0_place': 349, 'wi_id': 1260, 'wi': 'fun', 'loss_estimate': 0.26601442694664}
# flip time: 5
# {'w0': 'chevy', 'w0_place': 7, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.12452679872512817}
# mean loss increased record: -0.14935717582702637
# doc_num: 19
# average up to now: 0.34576510000777877
# loss before hotflip: 0.006483117118477821
# negR_858.txt
# flip time: 1
# {'w0': 'film', 'w0_place': 2, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.0054631480015814304}
# flip time: 2
# {'w0': 'haunting', 'w0_place': 1, 'wi_id': 1158, 'wi': 'contact', 'loss_estimate': 0.15052594244480133}
# flip time: 3
# {'w0': 'the', 'w0_place': 0, 'wi_id': 86, 'wi': 'no', 'loss_estimate': 0.645661473274231}
# flip time: 4
# {'w0': 'one', 'w0_place': 718, 'wi_id': 1260, 'wi': 'fun', 'loss_estimate': 0.46102333068847656}
# flip time: 5
# {'w0': 'true', 'w0_place': 9, 'wi_id': 764, 'wi': 'personal', 'loss_estimate': 0.35345470905303955}
# mean loss increased record: 0.8047692220658064
# doc_num: 20
# average up to now: 0.36871530611068015
# loss before hotflip: 0.02395857311785221
# negR_861.txt
# flip time: 1
# {'w0': 'film', 'w0_place': 6, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.016414999961853027}
# flip time: 2
# {'w0': 'had', 'w0_place': 1, 'wi_id': 211, 'wi': 'set', 'loss_estimate': 0.30871644616127014}
# flip time: 3
# {'w0': 'i', 'w0_place': 0, 'wi_id': 1158, 'wi': 'contact', 'loss_estimate': 1.014621376991272}
# flip time: 4
# {'w0': 'been', 'w0_place': 2, 'wi_id': 211, 'wi': 'set', 'loss_estimate': 0.43016311526298523}
# flip time: 5
# {'w0': 'heard', 'w0_place': 9, 'wi_id': 211, 'wi': 'set', 'loss_estimate': 0.2519912123680115}
# mean loss increased record: 0.5826798181980848
# doc_num: 21
# average up to now: 0.37890409240055656
# loss before hotflip: 0.022049514576792717
# negR_864.txt
# flip time: 1
# {'w0': 'i', 'w0_place': 0, 'wi_id': 1973, 'wi': 'screen', 'loss_estimate': 0.02696051634848118}
# flip time: 2
# {'w0': 'is', 'w0_place': 4, 'wi_id': 986, 'wi': 'remains', 'loss_estimate': 0.3084014356136322}
# flip time: 3
# {'w0': 'criterion', 'w0_place': 7, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.6724528074264526}
# flip time: 4
# {'w0': 'at', 'w0_place': 5, 'wi_id': 1124, 'wi': 'toward', 'loss_estimate': 0.31989309191703796}
# flip time: 5
# {'w0': 'all', 'w0_place': 6, 'wi_id': 86, 'wi': 'no', 'loss_estimate': 0.1130688339471817}
# mean loss increased record: 0.416462642326951
# doc_num: 22
# average up to now: 0.3806112992153927
# loss before hotflip: 0.02845298871397972
# negR_867.txt
# flip time: 1
# {'w0': 'government', 'w0_place': 3, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.036631159484386444}
# flip time: 2
# {'w0': 'u', 'w0_place': 1, 'wi_id': 1865, 'wi': 'suspect', 'loss_estimate': 0.7531511783599854}
# flip time: 3
# {'w0': 's', 'w0_place': 2, 'wi_id': 1158, 'wi': 'contact', 'loss_estimate': 0.5649727582931519}
# flip time: 4
# {'w0': 'been', 'w0_place': 649, 'wi_id': 1260, 'wi': 'fun', 'loss_estimate': 0.3017185926437378}
# flip time: 5
# {'w0': 'better', 'w0_place': 650, 'wi_id': 1134, 'wi': 'winner', 'loss_estimate': 0.48071959614753723}
# mean loss increased record: 0.5820941217243671
# doc_num: 23
# average up to now: 0.3893714219331742
# loss before hotflip: 0.035776134580373764
# negR_870.txt
# flip time: 1
# {'w0': 'have', 'w0_place': 3, 'wi_id': 1422, 'wi': 'gold', 'loss_estimate': 0.027066044509410858}
# flip time: 2
# {'w0': 'days', 'w0_place': 1, 'wi_id': 360, 'wi': 'times', 'loss_estimate': 0.7009806632995605}
# flip time: 3
# {'w0': 'these', 'w0_place': 0, 'wi_id': 86, 'wi': 'no', 'loss_estimate': 0.7547979354858398}
# flip time: 4
# {'w0': 'attention', 'w0_place': 6, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.5181576013565063}
# flip time: 5
# {'w0': 'rather', 'w0_place': 4, 'wi_id': 138, 'wi': 'very', 'loss_estimate': 0.3115944266319275}
# mean loss increased record: 0.8772241599857807
# doc_num: 24
# average up to now: 0.40969861935203283
# loss before hotflip: 1.5215798616409302
# negR_873.txt
# flip time: 1
# {'w0': '1963', 'w0_place': 3, 'wi_id': 81, 'wi': 'million', 'loss_estimate': 1.2731159925460815}
# flip time: 2
# {'w0': 'remake', 'w0_place': 1, 'wi_id': 1180, 'wi': 'serve', 'loss_estimate': 0.612578272819519}
# flip time: 3
# {'w0': 'the', 'w0_place': 2, 'wi_id': 86, 'wi': 'no', 'loss_estimate': 0.22927765548229218}
# flip time: 4
# {'w0': 'haunting', 'w0_place': 18, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.15087437629699707}
# flip time: 5
# {'w0': 'shirley', 'w0_place': 12, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.0627126395702362}
# mean loss increased record: 0.1725691080093384
# doc_num: 25
# average up to now: 0.400213438898325
# loss before hotflip: 2.7346112728118896
# negR_876.txt
# flip time: 1
# {'w0': 'life', 'w0_place': 0, 'wi_id': 1158, 'wi': 'contact', 'loss_estimate': 1.5048925876617432}
# flip time: 2
# {'w0': 'while', 'w0_place': 4, 'wi_id': 1124, 'wi': 'toward', 'loss_estimate': 0.5379707217216492}
# flip time: 3
# {'w0': 'jordan', 'w0_place': 663, 'wi_id': 1260, 'wi': 'fun', 'loss_estimate': 0.4783061146736145}
# flip time: 4
# {'w0': '--michael', 'w0_place': 662, 'wi_id': 77, 'wi': 'years', 'loss_estimate': 0.34502407908439636}
# flip time: 5
# {'w0': '"', 'w0_place': 661, 'wi_id': 1260, 'wi': 'fun', 'loss_estimate': 0.27884045243263245}
# mean loss increased record: 0.7219451427459717
# doc_num: 26
# average up to now: 0.41258773520015757
# loss before hotflip: 0.0016763457097113132
# negR_879.txt
# flip time: 1
# {'w0': '"', 'w0_place': 0, 'wi_id': 1973, 'wi': 'screen', 'loss_estimate': 0.0015484316973015666}
# flip time: 2
# {'w0': 'return', 'w0_place': 1, 'wi_id': 1973, 'wi': 'screen', 'loss_estimate': 0.037108249962329865}
# flip time: 3
# {'w0': 'film', 'w0_place': 14, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.10455217957496643}
# flip time: 4
# {'w0': 'at', 'w0_place': 11, 'wi_id': 1124, 'wi': 'toward', 'loss_estimate': 0.14566630125045776}
# flip time: 5
# {'w0': 'wants', 'w0_place': 5, 'wi_id': 986, 'wi': 'remains', 'loss_estimate': 0.17234428226947784}
# mean loss increased record: 0.38502432806417347
# doc_num: 27
# average up to now: 0.41156686826919514
# loss before hotflip: 0.047719839960336685
# negR_882.txt
# flip time: 1
# {'w0': 'p', 'w0_place': 7, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.06210203468799591}
# flip time: 2
# {'w0': 'seen', 'w0_place': 0, 'wi_id': 211, 'wi': 'set', 'loss_estimate': 0.8812060356140137}
# flip time: 3
# {'w0': '1997', 'w0_place': 3, 'wi_id': 81, 'wi': 'million', 'loss_estimate': 1.0324440002441406}
# flip time: 4
# {'w0': 'december', 'w0_place': 1, 'wi_id': 34, 'wi': '$', 'loss_estimate': 0.34179359674453735}
# flip time: 5
# {'w0': '50', 'w0_place': 6, 'wi_id': 81, 'wi': 'million', 'loss_estimate': 0.1906929612159729}
# mean loss increased record: 0.7920247308909893
# doc_num: 28
# average up to now: 0.4251546490771164
# loss before hotflip: 3.5069804191589355
# negR_885.txt
# flip time: 1
# {'w0': 'released', 'w0_place': 6, 'wi_id': 1123, 'wi': 'forced', 'loss_estimate': 1.1756266355514526}
# flip time: 2
# {'w0': 'this', 'w0_place': 8, 'wi_id': 223, 'wi': 'each', 'loss_estimate': 0.14966651797294617}
# flip time: 3
# {'w0': 'aptly', 'w0_place': 12, 'wi_id': 1771, 'wi': 'perhaps', 'loss_estimate': 0.06120457872748375}
# flip time: 4
# {'w0': 'plastic', 'w0_place': 17, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.039903514087200165}
# flip time: 5
# {'w0': 'two', 'w0_place': 16, 'wi_id': 81, 'wi': 'million', 'loss_estimate': 0.009486759081482887}
# mean loss increased record: -0.15145430564880372
# doc_num: 29
# average up to now: 0.40527158167277433
# loss before hotflip: 0.09479822963476181
# negR_888.txt
# flip time: 1
# {'w0': 'kid', 'w0_place': 2, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.14068035781383514}
# flip time: 2
# {'w0': 'spoiled', 'w0_place': 0, 'wi_id': 1725, 'wi': 'entered', 'loss_estimate': 0.8889257907867432}
# flip time: 3
# {'w0': 'present', 'w0_place': 12, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.4316778779029846}
# flip time: 4
# {'w0': 'rich', 'w0_place': 1, 'wi_id': 678, 'wi': 'annual', 'loss_estimate': 0.5682185888290405}
# flip time: 5
# {'w0': 'kelley', 'w0_place': 3, 'wi_id': 1158, 'wi': 'contact', 'loss_estimate': 0.4038313627243042}
# mean loss increased record: 0.5336621955037117
# doc_num: 30
# average up to now: 0.40955126880047227
# loss before hotflip: 1.5824940204620361
# negR_891.txt
# flip time: 1
# {'w0': 'on', 'w0_place': 1, 'wi_id': 1124, 'wi': 'toward', 'loss_estimate': 1.3431484699249268}
# flip time: 2
# {'w0': 'acumen', 'w0_place': 5, 'wi_id': 992, 'wi': 'questions', 'loss_estimate': 0.6369370222091675}
# flip time: 3
# {'w0': 'your', 'w0_place': 2, 'wi_id': 30, 'wi': 'their', 'loss_estimate': 0.33902889490127563}
# flip time: 4
# {'w0': 'about', 'w0_place': 765, 'wi_id': 406, 'wi': 'along', 'loss_estimate': 0.2898041605949402}
# flip time: 5
# {'w0': 'was', 'w0_place': 764, 'wi_id': 1860, 'wi': 'excited', 'loss_estimate': 0.4424474239349365}
# mean loss increased record: 0.6664562702178956
# doc_num: 31
# average up to now: 0.41783852691071177
# loss before hotflip: 0.14300298690795898
# negR_894.txt
# flip time: 1
# {'w0': 'giving', 'w0_place': 2, 'wi_id': 798, 'wi': 'opening', 'loss_estimate': 0.1324685513973236}
# flip time: 2
# {'w0': "'m", 'w0_place': 1, 'wi_id': 1865, 'wi': 'suspect', 'loss_estimate': 0.9672104120254517}
# flip time: 3
# {'w0': 'i', 'w0_place': 0, 'wi_id': 678, 'wi': 'annual', 'loss_estimate': 1.000503420829773}
# flip time: 4
# {'w0': 'movie', 'w0_place': 13, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.740802526473999}
# flip time: 5
# {'w0': 'stinker', 'w0_place': 4, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.34913888573646545}
# mean loss increased record: 0.637218427658081
# doc_num: 32
# average up to now: 0.42469414880906703
# loss before hotflip: 0.0026277319993823767
# negR_897.txt
# flip time: 1
# {'w0': 'struggling', 'w0_place': 2, 'wi_id': 798, 'wi': 'opening', 'loss_estimate': 0.002800691407173872}
# flip time: 2
# {'w0': 'novelist', 'w0_place': 1, 'wi_id': 1158, 'wi': 'contact', 'loss_estimate': 0.12567682564258575}
# flip time: 3
# {'w0': 'work', 'w0_place': 6, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.7481497526168823}
# flip time: 4
# {'w0': 'brain', 'w0_place': 9, 'wi_id': 576, 'wi': 'history', 'loss_estimate': 0.5285955667495728}
# flip time: 5
# {'w0': 'weird', 'w0_place': 8, 'wi_id': 764, 'wi': 'personal', 'loss_estimate': 0.15378527343273163}
# mean loss increased record: 0.5068354364950209
# doc_num: 33
# average up to now: 0.4271832787389444
# loss before hotflip: 0.06710494309663773
# posR_800.txt
# flip time: 1
# {'w0': 'reviews', 'w0_place': 6, 'wi_id': 1636, 'wi': 'boys', 'loss_estimate': 0.057669125497341156}
# flip time: 2
# {'w0': 'surprised', 'w0_place': 11, 'wi_id': 811, 'wi': 'create', 'loss_estimate': 1.277771234512329}
# flip time: 3
# {'w0': 'frequently', 'w0_place': 3, 'wi_id': 138, 'wi': 'very', 'loss_estimate': 0.7865002155303955}
# flip time: 4
# {'w0': 'likely', 'w0_place': 9, 'wi_id': 678, 'wi': 'annual', 'loss_estimate': 0.28500431776046753}
# flip time: 5
# {'w0': 'who', 'w0_place': 2, 'wi_id': 1791, 'wi': 'whom', 'loss_estimate': 0.17242096364498138}
# mean loss increased record: 0.5062093958258629
# doc_num: 34
# average up to now: 0.4295075763003244
# loss before hotflip: 2.018033742904663
# posR_803.txt
# flip time: 1
# {'w0': 'moment', 'w0_place': 4, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.8703632354736328}
# flip time: 2
# {'w0': 'is', 'w0_place': 9, 'wi_id': 1530, 'wi': 'appears', 'loss_estimate': 0.3840842843055725}
# flip time: 3
# {'w0': 'late', 'w0_place': 5, 'wi_id': 227, 'wi': 'here', 'loss_estimate': 0.35963380336761475}
# flip time: 4
# {'w0': 'movie', 'w0_place': 19, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.13979044556617737}
# flip time: 5
# {'w0': 'robert', 'w0_place': 7, 'wi_id': 302, 'wi': 'financial', 'loss_estimate': 0.11211997270584106}
# mean loss increased record: 0.031921911239624026
# doc_num: 35
# average up to now: 0.41814798587001867
# loss before hotflip: 0.06231534481048584
# posR_806.txt
# flip time: 1
# {'w0': 'casted', 'w0_place': 4, 'wi_id': 302, 'wi': 'financial', 'loss_estimate': 0.09013219177722931}
# flip time: 2
# {'w0': 'is', 'w0_place': 2, 'wi_id': 1530, 'wi': 'appears', 'loss_estimate': 1.0908896923065186}
# flip time: 3
# {'w0': 'bruce', 'w0_place': 0, 'wi_id': 153, 'wi': 'think', 'loss_estimate': 1.0456347465515137}
# flip time: 4
# {'w0': 'willis', 'w0_place': 1, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.5181142687797546}
# flip time: 5
# {'w0': 'he', 'w0_place': 9, 'wi_id': 74, 'wi': 'she', 'loss_estimate': 0.24477455019950867}
# mean loss increased record: 0.5963659048080444
# doc_num: 36
# average up to now: 0.42309848361829716
# loss before hotflip: 4.4392852783203125
# posR_809.txt
# flip time: 1
# {'w0': 'daisy', 'w0_place': 2, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 1.4430158138275146}
# flip time: 2
# {'w0': 'time', 'w0_place': 6, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.5002437829971313}
# flip time: 3
# {'w0': 'film', 'w0_place': 18, 'wi_id': 1444, 'wi': 'worst', 'loss_estimate': 0.25145331025123596}
# flip time: 4
# {'w0': 'story', 'w0_place': 10, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.12082886695861816}
# flip time: 5
# {'w0': 'innumerable', 'w0_place': 29, 'wi_id': 302, 'wi': 'financial', 'loss_estimate': 0.034341998398303986}
# mean loss increased record: -0.306855583190918
# doc_num: 37
# average up to now: 0.4033699953261562
# loss before hotflip: 0.019625883549451828
# posR_812.txt
# flip time: 1
# {'w0': '18', 'w0_place': 11, 'wi_id': 595, 'wi': 'nine', 'loss_estimate': 0.021314753219485283}
# flip time: 2
# {'w0': 'crossgates', 'w0_place': 9, 'wi_id': 763, 'wi': 'efforts', 'loss_estimate': 0.7902265787124634}
# flip time: 3
# {'w0': 'april', 'w0_place': 1, 'wi_id': 227, 'wi': 'here', 'loss_estimate': 1.3138890266418457}
# flip time: 4
# {'w0': 'seen', 'w0_place': 0, 'wi_id': 1550, 'wi': 'arrived', 'loss_estimate': 0.768264889717102}
# flip time: 5
# {'w0': 'at', 'w0_place': 4, 'wi_id': 405, 'wi': 'within', 'loss_estimate': 0.38231849670410156}
# mean loss increased record: 0.718732837587595
# doc_num: 38
# average up to now: 0.4116690174909309
# loss before hotflip: 4.726841449737549
# posR_815.txt
# flip time: 1
# {'w0': 'be', 'w0_place': 5, 'wi_id': 1444, 'wi': 'worst', 'loss_estimate': 0.934597373008728}
# flip time: 2
# {'w0': "'d", 'w0_place': 1, 'wi_id': 130, 'wi': 'should', 'loss_estimate': 0.6291966438293457}
# flip time: 3
# {'w0': 'think', 'w0_place': 2, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.36849483847618103}
# flip time: 4
# {'w0': 'it', 'w0_place': 3, 'wi_id': 74, 'wi': 'she', 'loss_estimate': 0.10900186002254486}
# flip time: 5
# {'w0': 'try', 'w0_place': 11, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.087601438164711}
# mean loss increased record: -0.3187817096710205
# doc_num: 39
# average up to now: 0.39293951166626545
# loss before hotflip: 0.7035302519798279
# posR_818.txt
# flip time: 1
# {'w0': 'stunned', 'w0_place': 9, 'wi_id': 1064, 'wi': 'accused', 'loss_estimate': 0.42945343255996704}
# flip time: 2
# {'w0': 'years', 'w0_place': 5, 'wi_id': 763, 'wi': 'efforts', 'loss_estimate': 0.8993951082229614}
# flip time: 3
# {'w0': 'long', 'w0_place': 4, 'wi_id': 302, 'wi': 'financial', 'loss_estimate': 1.4386885166168213}
# flip time: 4
# {'w0': 'has', 'w0_place': 1, 'wi_id': 1135, 'wi': 'hopes', 'loss_estimate': 0.2661297023296356}
# flip time: 5
# {'w0': 'world', 'w0_place': 12, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.18366563320159912}
# mean loss increased record: 0.42512041330337524
# doc_num: 40
# average up to now: 0.3937440342071932
# loss before hotflip: 1.0080182552337646
# posR_821.txt
# flip time: 1
# {'w0': 'masseuse', 'w0_place': 7, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.726085364818573}
# flip time: 2
# {'w0': 'goofy', 'w0_place': 6, 'wi_id': 1990, 'wi': 'failure', 'loss_estimate': 1.2612929344177246}
# flip time: 3
# {'w0': 'an', 'w0_place': 0, 'wi_id': 27, 'wi': 'an', 'loss_estimate': 0.7272114157676697}
# flip time: 4
# {'w0': 'unhappy', 'w0_place': 1, 'wi_id': 480, 'wi': 'believe', 'loss_estimate': 0.3215262293815613}
# flip time: 5
# {'w0': 'believe', 'w0_place': 1, 'wi_id': 64, 'wi': 'last', 'loss_estimate': 0.2219882756471634}
# mean loss increased record: 0.3550684452056885
# doc_num: 41
# average up to now: 0.39280072715837605
# loss before hotflip: 0.007347347680479288
# posR_824.txt
# flip time: 1
# {'w0': 'spielberg', 'w0_place': 8, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.010547073557972908}
# flip time: 2
# {'w0': 'years', 'w0_place': 5, 'wi_id': 763, 'wi': 'efforts', 'loss_estimate': 0.2537461817264557}
# flip time: 3
# {'w0': '1977', 'w0_place': 2, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 1.717150092124939}
# flip time: 4
# {'w0': 'may', 'w0_place': 1, 'wi_id': 47, 'wi': 'would', 'loss_estimate': 0.5676873922348022}
# flip time: 5
# {'w0': 'after', 'w0_place': 6, 'wi_id': 405, 'wi': 'within', 'loss_estimate': 0.08602012693881989}
# mean loss increased record: 0.5021989817731083
# doc_num: 42
# average up to now: 0.3954054475063459
# loss before hotflip: 0.013412367552518845
# posR_827.txt
# flip time: 1
# {'w0': 'only', 'w0_place': 2, 'wi_id': 227, 'wi': 'here', 'loss_estimate': 0.008993616327643394}
# flip time: 2
# {'w0': 'was', 'w0_place': 1, 'wi_id': 9, 'wi': 'said', 'loss_estimate': 0.14134036004543304}
# flip time: 3
# {'w0': 'time', 'w0_place': 4, 'wi_id': 1428, 'wi': 'partner', 'loss_estimate': 0.48409396409988403}
# flip time: 4
# {'w0': 'before', 'w0_place': 5, 'wi_id': 3, 'wi': 'that', 'loss_estimate': 0.4026828408241272}
# flip time: 5
# {'w0': 'dilbert', 'w0_place': 6, 'wi_id': 302, 'wi': 'financial', 'loss_estimate': 0.3074173927307129}
# mean loss increased record: 0.40589253678917886
# doc_num: 43
# average up to now: 0.395649333303621
# loss before hotflip: 0.31768858432769775
# posR_830.txt
# flip time: 1
# {'w0': 'more', 'w0_place': 1, 'wi_id': 1738, 'wi': 'older', 'loss_estimate': 0.5482813119888306}
# flip time: 2
# {'w0': 'america', 'w0_place': 9, 'wi_id': 598, 'wi': 'action', 'loss_estimate': 0.5457063913345337}
# flip time: 3
# {'w0': 'anjelica', 'w0_place': 4, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.5920301675796509}
# flip time: 4
# {'w0': 'for', 'w0_place': 0, 'wi_id': 369, 'wi': 'whether', 'loss_estimate': 0.4923832416534424}
# flip time: 5
# {'w0': 'than', 'w0_place': 2, 'wi_id': 369, 'wi': 'whether', 'loss_estimate': 0.31018373370170593}
# mean loss increased record: 0.3886615037918091
# doc_num: 44
# average up to now: 0.39549051899653437
# loss before hotflip: 0.0753798633813858
# posR_833.txt
# flip time: 1
# {'w0': 'home', 'w0_place': 5, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.1438787877559662}
# flip time: 2
# {'w0': 'february', 'w0_place': 1, 'wi_id': 302, 'wi': 'financial', 'loss_estimate': 0.8358386158943176}
# flip time: 3
# {'w0': '1998', 'w0_place': 3, 'wi_id': 54, 'wi': 'two', 'loss_estimate': 0.6730359792709351}
# flip time: 4
# {'w0': '15', 'w0_place': 2, 'wi_id': 54, 'wi': 'two', 'loss_estimate': 0.5302938222885132}
# flip time: 5
# {'w0': 'financial', 'w0_place': 1, 'wi_id': 64, 'wi': 'last', 'loss_estimate': 0.5814944505691528}
# mean loss increased record: 0.4507289379835129
# doc_num: 45
# average up to now: 0.3967180394184672
# loss before hotflip: 5.072052478790283
# posR_836.txt
# flip time: 1
# {'w0': 'note', 'w0_place': 0, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.7341413497924805}
# flip time: 2
# {'w0': 'some', 'w0_place': 1, 'wi_id': 28, 'wi': 'this', 'loss_estimate': 0.3665847182273865}
# flip time: 3
# {'w0': 'forewarned', 'w0_place': 11, 'wi_id': 582, 'wi': 'released', 'loss_estimate': 0.3083997070789337}
# flip time: 4
# {'w0': 'the', 'w0_place': 5, 'wi_id': 166, 'wi': 'these', 'loss_estimate': 0.16061966121196747}
# flip time: 5
# {'w0': 'world', 'w0_place': 15, 'wi_id': 1990, 'wi': 'failure', 'loss_estimate': 0.02422209084033966}
# mean loss increased record: -0.4383843421936035
# doc_num: 46
# average up to now: 0.37856363981820484
# loss before hotflip: 2.547011137008667
# posR_839.txt
# flip time: 1
# {'w0': 'assume', 'w0_place': 0, 'wi_id': 21, 'wi': 'have', 'loss_estimate': 1.1875653266906738}
# flip time: 2
# {'w0': 'impressions', 'w0_place': 15, 'wi_id': 763, 'wi': 'efforts', 'loss_estimate': 0.3463575541973114}
# flip time: 3
# {'w0': 'nothing', 'w0_place': 1, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.4768213629722595}
# flip time: 4
# {'w0': 'the', 'w0_place': 10, 'wi_id': 184, 'wi': 'both', 'loss_estimate': 0.15099206566810608}
# flip time: 5
# {'w0': 'first', 'w0_place': 14, 'wi_id': 1444, 'wi': 'worst', 'loss_estimate': 0.03032899647951126}
# mean loss increased record: 0.08027348518371583
# doc_num: 47
# average up to now: 0.3722170407834285
# loss before hotflip: 0.01914031058549881
# posR_842.txt
# flip time: 1
# {'w0': 'butthead', 'w0_place': 2, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.023387514054775238}
# flip time: 2
# {'w0': 'if', 'w0_place': 0, 'wi_id': 369, 'wi': 'whether', 'loss_estimate': 0.6166703104972839}
# flip time: 3
# {'w0': 'beavis', 'w0_place': 1, 'wi_id': 153, 'wi': 'think', 'loss_estimate': 0.9818259477615356}
# flip time: 4
# {'w0': 'favorite', 'w0_place': 4, 'wi_id': 302, 'wi': 'financial', 'loss_estimate': 0.6527581214904785}
# flip time: 5
# {'w0': 'by', 'w0_place': 15, 'wi_id': 405, 'wi': 'within', 'loss_estimate': 0.3627687394618988}
# mean loss increased record: 0.8046366557478905
# doc_num: 48
# average up to now: 0.3812257827618548
# loss before hotflip: 2.345363140106201
# posR_845.txt
# flip time: 1
# {'w0': 'film', 'w0_place': 7, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.5761897563934326}
# flip time: 2
# {'w0': 'when', 'w0_place': 0, 'wi_id': 139, 'wi': 'how', 'loss_estimate': 0.6917641162872314}
# flip time: 3
# {'w0': 'saw', 'w0_place': 2, 'wi_id': 582, 'wi': 'released', 'loss_estimate': 0.5803679823875427}
# flip time: 4
# {'w0': 'laughed', 'w0_place': 9, 'wi_id': 1161, 'wi': 'dead', 'loss_estimate': 0.2239103615283966}
# flip time: 5
# {'w0': 'released', 'w0_place': 2, 'wi_id': 92, 'wi': 'did', 'loss_estimate': 0.1636609435081482}
# mean loss increased record: 0.2910149574279785
# doc_num: 49
# average up to now: 0.37938474551014306
# loss before hotflip: 0.11040335893630981
# posR_848.txt
# flip time: 1
# {'w0': 'age', 'w0_place': 6, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.16564129292964935}
# flip time: 2
# {'w0': 'old', 'w0_place': 5, 'wi_id': 302, 'wi': 'financial', 'loss_estimate': 1.6662781238555908}
# flip time: 3
# {'w0': 'ripe', 'w0_place': 4, 'wi_id': 389, 'wi': 'include', 'loss_estimate': 0.611078679561615}
# flip time: 4
# {'w0': 'clint', 'w0_place': 0, 'wi_id': 838, 'wi': 'everything', 'loss_estimate': 0.5035417079925537}
# flip time: 5
# {'w0': 'eastwood', 'w0_place': 1, 'wi_id': 991, 'wi': 'address', 'loss_estimate': 0.45198941230773926}
# mean loss increased record: 0.7216885924339295
# doc_num: 50
# average up to now: 0.3862308224486188
# loss before hotflip: 0.007923007942736149
# posR_851.txt
# flip time: 1
# {'w0': 'man', 'w0_place': 3, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.004954655189067125}
# flip time: 2
# {'w0': 'hypnotized', 'w0_place': 2, 'wi_id': 582, 'wi': 'released', 'loss_estimate': 0.6764612197875977}
# flip time: 3
# {'w0': 'after', 'w0_place': 0, 'wi_id': 108, 'wi': 'through', 'loss_estimate': 1.0753040313720703}
# flip time: 4
# {'w0': 'believes', 'w0_place': 4, 'wi_id': 870, 'wi': 'lives', 'loss_estimate': 0.45572760701179504}
# flip time: 5
# {'w0': 'in', 'w0_place': 8, 'wi_id': 405, 'wi': 'within', 'loss_estimate': 0.2089560180902481}
# mean loss increased record: 0.6150789020583034
# doc_num: 51
# average up to now: 0.3907180396958675
# loss before hotflip: 3.957099676132202
# posR_854.txt
# flip time: 1
# {'w0': 'students', 'w0_place': 2, 'wi_id': 763, 'wi': 'efforts', 'loss_estimate': 1.391733169555664}
# flip time: 2
# {'w0': 'many', 'w0_place': 1, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.6702496409416199}
# flip time: 3
# {'w0': 'efforts', 'w0_place': 2, 'wi_id': 809, 'wi': 'kids', 'loss_estimate': 0.2204347401857376}
# flip time: 4
# {'w0': 'such', 'w0_place': 7, 'wi_id': 302, 'wi': 'financial', 'loss_estimate': 0.2868572175502777}
# flip time: 5
# {'w0': 'would', 'w0_place': 23, 'wi_id': 130, 'wi': 'should', 'loss_estimate': 0.2916398346424103}
# mean loss increased record: -0.04888472557067871
# doc_num: 52
# average up to now: 0.3822641403638185
# loss before hotflip: 2.7792885303497314
# posR_857.txt
# flip time: 1
# {'w0': 'look', 'w0_place': 2, 'wi_id': 19, 'wi': 'are', 'loss_estimate': 1.2168703079223633}
# flip time: 2
# {'w0': 'perfection', 'w0_place': 9, 'wi_id': 318, 'wi': 'line', 'loss_estimate': 0.4929587244987488}
# flip time: 3
# {'w0': 'is', 'w0_place': 6, 'wi_id': 1530, 'wi': 'appears', 'loss_estimate': 0.18983115255832672}
# flip time: 4
# {'w0': 'for', 'w0_place': 3, 'wi_id': 108, 'wi': 'through', 'loss_estimate': 0.13539159297943115}
# flip time: 5
# {'w0': 'not', 'w0_place': 7, 'wi_id': 227, 'wi': 'here', 'loss_estimate': 0.08216245472431183}
# mean loss increased record: 0.4960449695587158
# doc_num: 53
# average up to now: 0.3844109484618355
# loss before hotflip: 0.011631764471530914
# posR_860.txt
# flip time: 1
# {'w0': 'chilling', 'w0_place': 3, 'wi_id': 125, 'wi': 'going', 'loss_estimate': 0.013500013388693333}
# flip time: 2
# {'w0': 'verdict', 'w0_place': 1, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 1.0189030170440674}
# flip time: 3
# {'w0': 'the', 'w0_place': 0, 'wi_id': 28, 'wi': 'this', 'loss_estimate': 0.7966760396957397}
# flip time: 4
# {'w0': 'horror', 'w0_place': 6, 'wi_id': 302, 'wi': 'financial', 'loss_estimate': 0.41565603017807007}
# flip time: 5
# {'w0': 'spine', 'w0_place': 2, 'wi_id': 991, 'wi': 'address', 'loss_estimate': 0.35698750615119934}
# mean loss increased record: 0.4678180143237114
# doc_num: 54
# average up to now: 0.3859555237555739
# loss before hotflip: 0.18591485917568207
# posR_863.txt
# flip time: 1
# {'w0': 'not', 'w0_place': 0, 'wi_id': 227, 'wi': 'here', 'loss_estimate': 0.209329754114151}
# flip time: 2
# {'w0': 'since', 'w0_place': 1, 'wi_id': 108, 'wi': 'through', 'loss_estimate': 0.8950734734535217}
# flip time: 3
# {'w0': 'film', 'w0_place': 13, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.525529146194458}
# flip time: 4
# {'w0': 'i', 'w0_place': 11, 'wi_id': 763, 'wi': 'efforts', 'loss_estimate': 0.32929861545562744}
# flip time: 5
# {'w0': 'have', 'w0_place': 10, 'wi_id': 389, 'wi': 'include', 'loss_estimate': 0.1827298104763031}
# mean loss increased record: 0.42618644535541533
# doc_num: 55
# average up to now: 0.38668699505738924
# loss before hotflip: 0.006663246545940638
# posR_866.txt
# flip time: 1
# {'w0': 'i', 'w0_place': 3, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.006574106402695179}
# flip time: 2
# {'w0': '"', 'w0_place': 0, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 1.1286543607711792}
# flip time: 3
# {'w0': 'see', 'w0_place': 5, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.7242748141288757}
# flip time: 4
# {'w0': 'could', 'w0_place': 4, 'wi_id': 130, 'wi': 'should', 'loss_estimate': 0.39982539415359497}
# flip time: 5
# {'w0': 'on', 'w0_place': 13, 'wi_id': 405, 'wi': 'within', 'loss_estimate': 0.3412870466709137}
# mean loss increased record: 0.7187194976024329
# doc_num: 56
# average up to now: 0.3926161468885507
# loss before hotflip: 4.277742385864258
# posR_869.txt
# flip time: 1
# {'w0': 'if', 'w0_place': 4, 'wi_id': 405, 'wi': 'within', 'loss_estimate': 0.8994457721710205}
# flip time: 2
# {'w0': 'ever', 'w0_place': 2, 'wi_id': 227, 'wi': 'here', 'loss_estimate': 0.7032092809677124}
# flip time: 3
# {'w0': 'you', 'w0_place': 1, 'wi_id': 74, 'wi': 'she', 'loss_estimate': 0.31859391927719116}
# flip time: 4
# {'w0': 'is', 'w0_place': 6, 'wi_id': 1530, 'wi': 'appears', 'loss_estimate': 0.10829160362482071}
# flip time: 5
# {'w0': 'in', 'w0_place': 16, 'wi_id': 405, 'wi': 'within', 'loss_estimate': 0.030274484306573868}
# mean loss increased record: -0.2973968505859375
# doc_num: 57
# average up to now: 0.38051065570478776
# loss before hotflip: 3.902806043624878
# posR_872.txt
# flip time: 1
# {'w0': 'playing', 'w0_place': 6, 'wi_id': 125, 'wi': 'going', 'loss_estimate': 0.8891632556915283}
# flip time: 2
# {'w0': 'very', 'w0_place': 3, 'wi_id': 227, 'wi': 'here', 'loss_estimate': 0.5832443833351135}
# flip time: 3
# {'w0': 'robert', 'w0_place': 0, 'wi_id': 1111, 'wi': 'ask', 'loss_estimate': 0.5479132533073425}
# flip time: 4
# {'w0': 'characters', 'w0_place': 7, 'wi_id': 763, 'wi': 'efforts', 'loss_estimate': 0.11762687563896179}
# flip time: 5
# {'w0': 'have', 'w0_place': 9, 'wi_id': 1990, 'wi': 'failure', 'loss_estimate': 0.029645953327417374}
# mean loss increased record: -0.04936962127685547
# doc_num: 58
# average up to now: 0.3730989267913111
# loss before hotflip: 0.0014222278259694576
# posR_875.txt
# flip time: 1
# {'w0': 'once', 'w0_place': 1, 'wi_id': 227, 'wi': 'here', 'loss_estimate': 0.0007619103416800499}
# flip time: 2
# {'w0': 'every', 'w0_place': 0, 'wi_id': 28, 'wi': 'this', 'loss_estimate': 0.038206424564123154}
# flip time: 3
# {'w0': 'an', 'w0_place': 5, 'wi_id': 3, 'wi': 'that', 'loss_estimate': 0.4487093985080719}
# flip time: 4
# {'w0': 'exceptional', 'w0_place': 6, 'wi_id': 302, 'wi': 'financial', 'loss_estimate': 0.5551727414131165}
# flip time: 5
# {'w0': 'family', 'w0_place': 7, 'wi_id': 389, 'wi': 'include', 'loss_estimate': 0.2881307005882263}
# mean loss increased record: 0.4302235004492104
# doc_num: 59
# average up to now: 0.37406713990415685
# loss before hotflip: 0.019046278670430183
# posR_878.txt
# flip time: 1
# {'w0': 'know', 'w0_place': 2, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.011121205985546112}
# flip time: 2
# {'w0': 'did', 'w0_place': 5, 'wi_id': 582, 'wi': 'released', 'loss_estimate': 0.34908729791641235}
# flip time: 3
# {'w0': 'last', 'w0_place': 6, 'wi_id': 302, 'wi': 'financial', 'loss_estimate': 0.8200306296348572}
# flip time: 4
# {'w0': 'first', 'w0_place': 10, 'wi_id': 302, 'wi': 'financial', 'loss_estimate': 0.25667205452919006}
# flip time: 5
# {'w0': '"', 'w0_place': 8, 'wi_id': 582, 'wi': 'released', 'loss_estimate': 0.20665313303470612}
# mean loss increased record: 0.49899225793778895
# doc_num: 60
# average up to now: 0.37614922520471744
# loss before hotflip: 0.017891915515065193
# posR_881.txt
# flip time: 1
# {'w0': 'rest', 'w0_place': 3, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.021285925060510635}
# flip time: 2
# {'w0': 'the', 'w0_place': 0, 'wi_id': 28, 'wi': 'this', 'loss_estimate': 0.5282443761825562}
# flip time: 3
# {'w0': 'is', 'w0_place': 13, 'wi_id': 543, 'wi': 'costs', 'loss_estimate': 0.20235584676265717}
# flip time: 4
# {'w0': 'word', 'w0_place': 1, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.9622421264648438}
# flip time: 5
# {'w0': 'stressed', 'w0_place': 10, 'wi_id': 1444, 'wi': 'worst', 'loss_estimate': 0.32828807830810547}
# mean loss increased record: 0.4266548570245504
# doc_num: 61
# average up to now: 0.37697718638209177
# loss before hotflip: 0.11537156999111176
# posR_884.txt
# flip time: 1
# {'w0': 'farrelly', 'w0_place': 1, 'wi_id': 227, 'wi': 'here', 'loss_estimate': 0.11638034880161285}
# flip time: 2
# {'w0': 'film', 'w0_place': 5, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.7516766786575317}
# flip time: 3
# {'w0': 'after', 'w0_place': 6, 'wi_id': 746, 'wi': 'love', 'loss_estimate': 0.4305424094200134}
# flip time: 4
# {'w0': 'dumber', 'w0_place': 8, 'wi_id': 746, 'wi': 'love', 'loss_estimate': 0.1967531442642212}
# flip time: 5
# {'w0': 'real', 'w0_place': 16, 'wi_id': 302, 'wi': 'financial', 'loss_estimate': 0.1639392077922821}
# mean loss increased record: 0.787589481472969
# doc_num: 62
# average up to now: 0.38359996533517043
# loss before hotflip: 0.08649866282939911
# posR_887.txt
# flip time: 1
# {'w0': 'peter', 'w0_place': 8, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.139268159866333}
# flip time: 2
# {'w0': 'the', 'w0_place': 3, 'wi_id': 799, 'wi': 'either', 'loss_estimate': 1.0753724575042725}
# flip time: 3
# {'w0': 'somehow', 'w0_place': 2, 'wi_id': 1111, 'wi': 'ask', 'loss_estimate': 1.0325334072113037}
# flip time: 4
# {'w0': 'title', 'w0_place': 4, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.3345886468887329}
# flip time: 5
# {'w0': 'film', 'w0_place': 11, 'wi_id': 1990, 'wi': 'failure', 'loss_estimate': 0.012902962043881416}
# mean loss increased record: 0.9888774067163467
# doc_num: 63
# average up to now: 0.39320754376979233
# loss before hotflip: 4.187171459197998
# posR_890.txt
# flip time: 1
# {'w0': 'film', 'w0_place': 8, 'wi_id': 318, 'wi': 'line', 'loss_estimate': 0.4377503991127014}
# flip time: 2
# {'w0': 'is', 'w0_place': 2, 'wi_id': 1530, 'wi': 'appears', 'loss_estimate': 0.3665331304073334}
# flip time: 3
# {'w0': 'ron', 'w0_place': 18, 'wi_id': 598, 'wi': 'action', 'loss_estimate': 0.27481162548065186}
# flip time: 4
# {'w0': 'this', 'w0_place': 9, 'wi_id': 3, 'wi': 'that', 'loss_estimate': 0.06932250410318375}
# flip time: 5
# {'w0': 'summer', 'w0_place': 10, 'wi_id': 1990, 'wi': 'failure', 'loss_estimate': 0.052161894738674164}
# mean loss increased record: -0.32094101905822753
# doc_num: 64
# average up to now: 0.3820489724756045
# loss before hotflip: 0.5658445358276367
# posR_893.txt
# flip time: 1
# {'w0': 'love', 'w0_place': 8, 'wi_id': 389, 'wi': 'include', 'loss_estimate': 0.5286263227462769}
# flip time: 2
# {'w0': 'this', 'w0_place': 3, 'wi_id': 3, 'wi': 'that', 'loss_estimate': 1.0996811389923096}
# flip time: 3
# {'w0': 'open', 'w0_place': 2, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.8684982061386108}
# flip time: 4
# {'w0': 'movies', 'w0_place': 10, 'wi_id': 763, 'wi': 'efforts', 'loss_estimate': 0.11083727329969406}
# flip time: 5
# {'w0': 'adore', 'w0_place': 12, 'wi_id': 1161, 'wi': 'dead', 'loss_estimate': 0.04599675536155701}
# mean loss increased record: 0.797282600402832
# doc_num: 65
# average up to now: 0.38843718213602335
# loss before hotflip: 0.06517539173364639
# posR_896.txt
# flip time: 1
# {'w0': '"', 'w0_place': 3, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 0.07898092269897461}
# flip time: 2
# {'w0': 'condon', 'w0_place': 1, 'wi_id': 842, 'wi': 'talk', 'loss_estimate': 1.3526378870010376}
# flip time: 3
# {'w0': 'is', 'w0_place': 2, 'wi_id': 870, 'wi': 'lives', 'loss_estimate': 0.5311809778213501}
# flip time: 4
# {'w0': 'whale', 'w0_place': 20, 'wi_id': 302, 'wi': 'financial', 'loss_estimate': 0.2628147602081299}
# flip time: 5
# {'w0': 'last', 'w0_place': 12, 'wi_id': 302, 'wi': 'financial', 'loss_estimate': 0.36667877435684204}
# mean loss increased record: 0.49237668961286546
# doc_num: 66
# average up to now: 0.3900120231583997

# %%
t = torch.zeros(4,3,50)
print(t.shape)
a = t[:,:1,:]
print(a.shape)
# Out:
# torch.Size([4, 3, 50])
# torch.Size([4, 1, 50])
